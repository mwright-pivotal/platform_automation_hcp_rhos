# %%
# Clone ultralytics repo
#!git clone https://github.com/ultralytics/ultralytics

# Install dependencies
# !pip install -U -r ultralytics/examples/YOLOv8-Action-Recognition/requirements.txt

# %%
# Basic usage
# %pwd
# %cd ultralytics/examples/YOLOv8-Action-Recognition
# !pip uninstall -y opencv-python
# !pip install -q opencv-python-headless
#!python action_recognition.py --source "https://www.youtube.com/watch?v=dQw4w9WgXcQ" --labels "dancing" "singing a song" --output-path output.mp4
# Out:
# /home/jovyan/work/ultralytics/examples/YOLOv8-Action-Recognition
# WARNING: Skipping opencv-python as it is not installed.

# %%
import action_recognition

action_recognition.run(source="https://www.youtube.com/watch?v=dQw4w9WgXcQ", labels=["dancing","singing a song"], output_path="output.mp4")
# Out:
# 0: 384x640 1 person, 15.2ms
# Speed: 3.3ms preprocess, 15.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
